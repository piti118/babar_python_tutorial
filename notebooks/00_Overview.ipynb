# %% [markdown]
# ##Overview
#
# This notebook serves two purposes: testing out your installation and giving you a rough idea of what will be covered in this tutorial.

# %% [markdown]
# ###Basic python

# %% [markdown]
# ####hello world

# %%
print 'hello world'
# Out:
# hello world

# %% [markdown]
# ####And others

# %%
1+1
# Out:
# 2

# %%
for i in range(10):
    print 'loop', i
# Out:
# loop 0
# loop 1
# loop 2
# loop 3
# loop 4
# loop 5
# loop 6
# loop 7
# loop 8
# loop 9

# %% [markdown]
# ####Reading ROOT FILE

# %%
from root_numpy import root2rec

# %%
bb = root2rec('data/B*.root') #yep that simple
cc = root2rec('data/cc-BtoDpi-all.root')

# %% [markdown]
# ####And plotting

# %%
hist([bb.R2All, cc.R2All], bins=100, histtype='stepfilled', 
     color=['red','green'], alpha=0.5, label=[r'$B\bar{B}$',r'$c\bar{c}$']);
legend().get_frame().set_alpha(0.5)
title(r'My Amazing plot of R2All $\alpha$ $\beta$', fontsize='xx-large' )
xlabel('R2All')

# %% [markdown]
# ####Multivariate analysis

# %%
from sklearn import tree

# %%
X_sig= np.random.multivariate_normal(mean=[0.0, 0.0], cov=[ [1,0.5], [0.5,1] ], size= 1000)
X_bkg= np.random.rand(1000,2)
X_bkg= (X_bkg-0.5)*10
scatter(X_bkg[:,0], X_bkg[:,1], color='b', alpha=0.4)
scatter(X_sig[:,0], X_sig[:,1], color='g', alpha=0.4)

# %%
features = np.concatenate([X_sig, X_bkg])
classes = np.array( [0]*len(X_bkg) + [1]*len(X_sig) )

# %%
clf = tree.DecisionTreeClassifier(min_samples_leaf=10)

# %%
clf.fit(features, classes)
# Out:
# DecisionTreeClassifier(compute_importances=False, criterion='gini',
#             max_depth=None, max_features=None, min_density=0.1,
#             min_samples_leaf=10, min_samples_split=20,
#             random_state=<mtrand.RandomState object at 0x1002ab4e0>)

# %%
prediction = clf.predict(features)
print prediction.shape
print features[:,0].shape
# Out:
# (2000,)
# (2000,)

# %%
sig = features[prediction==1]
bg = features[prediction==0]
scatter(sig[:,0],sig[:,1],color='b', alpha=0.4)
scatter(bg[:,0],bg[:,1],color='g', alpha=0.4)
title('Prediction');

# %%
scatter(X_bkg[:,0], X_bkg[:,1], color='b', alpha=0.4)
scatter(X_sig[:,0], X_sig[:,1], color='g', alpha=0.4)
title('Original');

# %% [markdown]
# ####Fitting

# %%
from iminuit import Minuit
from probfit import UnbinnedLH, gaussian

# %%
data = randn(10000)
hist(data, bins=100, histtype='step');

# %%
ulh = UnbinnedLH(gaussian, data)
ulh.draw(args=dict(mean=1.2, sigma=0.7))

# %%
m = Minuit(ulh, mean=1.2, sigma=0.7)
# Out:
# -c:1: InitialParamWarning: Parameter mean is floating but does not have initial step size. Assume 1.
# -c:1: InitialParamWarning: Parameter sigma is floating but does not have initial step size. Assume 1.

# %%
m.migrad()
# Out:
# <hr>
#         <table>
#             <tr>
#                 <td>FCN = 14117.6714879</td>
#                 <td>NFCN = 58</td>
#                 <td>NCALLS = 58</td>
#             </tr>
#             <tr>
#                 <td>EDM = 5.83119803984e-09</td>
#                 <td>GOAL EDM = 5e-06</td>
#                 <td>UP = 0.5</td>
#             </tr>
#         </table>
#
#         <table>
#             <tr>
#                 <td align="center">Valid</td>
#                 <td align="center">Valid Param</td>
#                 <td align="center">Accurate Covar</td>
#                 <td align="center">PosDef</td>
#                 <td align="center">Made PosDef</td>
#             </tr>
#             <tr>
#                 <td align="center" style="background-color:#92CCA6">True</td>
#                 <td align="center" style="background-color:#92CCA6">True</td>
#                 <td align="center" style="background-color:#92CCA6">True</td>
#                 <td align="center" style="background-color:#92CCA6">True</td>
#                 <td align="center" style="background-color:#92CCA6">False</td>
#             </tr>
#             <tr>
#                 <td align="center">Hesse Fail</td>
#                 <td align="center">HasCov</td>
#                 <td align="center">Above EDM</td>
#                 <td align="center"></td>
#                 <td align="center">Reach calllim</td>
#             </tr>
#             <tr>
#                 <td align="center" style="background-color:#92CCA6">False</td>
#                 <td align="center" style="background-color:#92CCA6">True</td>
#                 <td align="center" style="background-color:#92CCA6">False</td>
#                 <td align="center"></td>
#                 <td align="center" style="background-color:#92CCA6">False</td>
#             </tr>
#         </table>
#         <table>
#             <tr>
#                 <td></td>
#                 <td>Name</td>
#                 <td>Value</td>
#                 <td>Parab Error</td>
#                 <td>Minos Error-</td>
#                 <td>Minos Error+</td>
#                 <td>Limit-</td>
#                 <td>Limit+</td>
#                 <td>FIXED</td>
#             </tr>
#
#             <tr>
#                 <td>1</td>
#                 <td>mean</td>
#                 <td>1.574988e-02</td>
#                 <td>9.928552e-03</td>
#                 <td>0.000000e+00</td>
#                 <td>0.000000e+00</td>
#                 <td></td>
#                 <td></td>
#                 <td></td>
#             </tr>
#
#             <tr>
#                 <td>2</td>
#                 <td>sigma</td>
#                 <td>9.928550e-01</td>
#                 <td>7.020551e-03</td>
#                 <td>0.000000e+00</td>
#                 <td>0.000000e+00</td>
#                 <td></td>
#                 <td></td>
#                 <td></td>
#             </tr>
#
#             </table>
# <hr>
# ({'hesse_failed': False, 'has_reached_call_limit': False, 'has_accurate_covar': True, 'has_posdef_covar': True, 'up': 0.5, 'edm': 5.831198039840541e-09, 'is_valid': True, 'is_above_max_edm': False, 'has_covariance': True, 'has_made_posdef_covar': False, 'has_valid_parameters': True, 'fval': 14117.671487859858, 'nfcn': 58},
#  [{'is_const': False, 'name': 'mean', 'has_limits': False, 'value': 0.01574987749650181, 'number': 0L, 'has_lower_limit': False, 'upper_limit': 0.0, 'lower_limit': 0.0, 'has_upper_limit': False, 'error': 0.009928551814735165, 'is_fixed': False},
#   {'is_const': False, 'name': 'sigma', 'has_limits': False, 'value': 0.9928550006666365, 'number': 1L, 'has_lower_limit': False, 'upper_limit': 0.0, 'lower_limit': 0.0, 'has_upper_limit': False, 'error': 0.007020551432236098, 'is_fixed': False}])

# %%
print m.values
print m.errors
ulh.draw(m)
# Out:
# {'sigma': 0.9928550006666365, 'mean': 0.01574987749650181}
# {'sigma': 0.007020551432236098, 'mean': 0.009928551814735165}
